# %% [markdown]
# # ANÁLISIS DESCRIPTIVO

# %%
import os
import pandas as pd
pd.set_option('display.max_columns', None)
current_dir = os.getcwd()
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales_path = os.path.join(current_dir, '../data/raw/Dataframe_Final_Data.csv')

sales = pd.read_csv(sales_path)

sales.head()
# Out:
#                                 id          item_id      dept_id     cat_id  \
# 0    HOBBIES_2_109_CA_2_evaluation    HOBBIES_2_109    HOBBIES_2    HOBBIES
# 1    HOBBIES_2_065_CA_2_evaluation    HOBBIES_2_065    HOBBIES_2    HOBBIES
# 2  HOUSEHOLD_1_027_WI_2_evaluation  HOUSEHOLD_1_027  HOUSEHOLD_1  HOUSEHOLD
# 3      FOODS_3_038_TX_3_evaluation      FOODS_3_038      FOODS_3      FOODS
# 4  HOUSEHOLD_1_466_CA_2_evaluation  HOUSEHOLD_1_466  HOUSEHOLD_1  HOUSEHOLD
#
#   store_id state_id    d  sales        date  wm_yr_wk   weekday  wday  \
# 0     CA_2       CA  d_1      0  2011-01-29     11101  Saturday     1
# 1     CA_2       CA  d_1      0  2011-01-29     11101  Saturday     1
# 2     WI_2       WI  d_1      0  2011-01-29     11101  Saturday     1
# 3     TX_3       TX  d_1      0  2011-01-29     11101  Saturday     1
# 4     CA_2       CA  d_1      0  2011-01-29     11101  Saturday     1
#
#      month  year event_name_1 event_type_1 event_name_2 event_type_2  snap_CA  \
# 0  2011-01  2011     No Event      No Type     No Event      No Type        0
# 1  2011-01  2011     No Event      No Type     No Event      No Type        0
# 2  2011-01  2011     No Event      No Type     No Event      No Type        0
# 3  2011-01  2011     No Event      No Type     No Event      No Type        0
# 4  2011-01  2011     No Event      No Type     No Event      No Type        0
#
#    snap_TX  snap_WI  sell_price  day_of_week  is_weekend  quarter  \
# 0        0        0        0.97            5           1        1
# 1        0        0        0.50            5           1        1
# 2        0        0        5.36            5           1        1
# 3        0        0        4.98            5           1        1
# 4        0        0        3.97            5           1        1
#
#    scaled_sell_price       pi_mean   poblacion  Crecimiento_p  pib_por_estado  \
# 0          -0.994920  2.954186e+07  37638369.0           0.82   728344.566667
# 1          -1.126161  2.954186e+07  37638369.0           0.82   728344.566667
# 2           0.230923  3.330011e+06   5705288.0           0.26    96791.900000
# 3           0.124813  4.231724e+06  25645629.0           1.71   449661.800000
# 4          -0.157214  2.954186e+07  37638369.0           0.82   728344.566667
#
#    riqueza_per_capita    wti
# 0        15065.000000  92.19
# 1        15065.000000  92.19
# 2        13536.666667  92.19
# 3        13775.000000  92.19
# 4        15065.000000  92.19

# %% [markdown]
# - Revisamos si encontramos datos nulos y el origen para ver si son coherentes con lo esperado.

# %%
isna_sum = sales.isna().sum()

isna_sum.sort_values(ascending = False)
# Out:
# id                    0
# item_id               0
# riqueza_per_capita    0
# pib_por_estado        0
# Crecimiento_p         0
# poblacion             0
# pi_mean               0
# scaled_sell_price     0
# quarter               0
# is_weekend            0
# day_of_week           0
# sell_price            0
# snap_WI               0
# snap_TX               0
# snap_CA               0
# event_type_2          0
# event_name_2          0
# event_type_1          0
# event_name_1          0
# year                  0
# month                 0
# wday                  0
# weekday               0
# wm_yr_wk              0
# date                  0
# sales                 0
# d                     0
# state_id              0
# store_id              0
# cat_id                0
# dept_id               0
# wti                   0
# dtype: int64

# %% [markdown]
# - Ahora seleccionamos las columnas sobre las que queremos analizar (media, mediana, moda, desviación estándar, rango, percentiles, cuartiles y la distribución (para ver si hay asimetría o se trata de una distribución normal))

# %%
sales.columns
# Out:
# Index(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'd',
#        'sales', 'date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI', 'sell_price', 'day_of_week',
#        'is_weekend', 'quarter', 'scaled_sell_price', 'pi_mean', 'poblacion',
#        'Crecimiento_p', 'pib_por_estado', 'riqueza_per_capita', 'wti'],
#       dtype='object')

# %% [markdown]
# - Vamos a analizar 100% las siguientes:  `sales`,
# `sell_price`,
# `scaled_sell_price`,
# `pi_mean`,
# `poblacion`,
# `Crecimiento_p`,
# `pib_por_estado`,
# `riqueza_per_capita`,
# `wti`.

# %% [markdown]
# - Analisarwmos tambien la linea de tiempo de las siguientes columnas: `sales`, `sell_price`, `wti`, `pi_mean`, `pib_por_estado`,  porque es clave ver su tendencia, estacionalidad o rupturas

# %%
sales.describe()
# Out:
#                sales       wm_yr_wk           wday           year  \
# count  970500.000000  970500.000000  970500.000000  970500.000000
# mean        1.164757   11343.166924       3.997424    2013.249356
# std         3.773697     152.859710       2.000643       1.556975
# min         0.000000   11101.000000       1.000000    2011.000000
# 25%         0.000000   11218.000000       2.000000    2012.000000
# 50%         0.000000   11335.000000       4.000000    2013.000000
# 75%         1.000000   11451.000000       6.000000    2015.000000
# max       315.000000   11617.000000       7.000000    2016.000000
#
#              snap_CA        snap_TX        snap_WI     sell_price  \
# count  970500.000000  970500.000000  970500.000000  970500.000000
# mean        0.329727       0.329727       0.329727       4.533018
# std         0.470114       0.470114       0.470114       3.581211
# min         0.000000       0.000000       0.000000       0.010000
# 25%         0.000000       0.000000       0.000000       2.180000
# 50%         0.000000       0.000000       0.000000       3.480000
# 75%         1.000000       1.000000       1.000000       5.940000
# max         1.000000       1.000000       1.000000      44.840000
#
#          day_of_week     is_weekend        quarter  scaled_sell_price  \
# count  970500.000000  970500.000000  970500.000000       9.705000e+05
# mean        3.002576       0.286450       2.446162       1.855977e-16
# std         2.000643       0.452103       1.118351       1.000001e+00
# min         0.000000       0.000000       1.000000      -1.262986e+00
# 25%         1.000000       0.000000       1.000000      -6.570457e-01
# 50%         3.000000       0.000000       2.000000      -2.940398e-01
# 75%         5.000000       1.000000       3.000000       3.928791e-01
# max         6.000000       1.000000       4.000000       1.125513e+01
#
#             pi_mean     poblacion  Crecimiento_p  pib_por_estado  \
# count  9.705000e+05  9.705000e+05  970500.000000   970500.000000
# mean   1.887001e+07  2.793229e+07       0.895323   560693.425754
# std    1.449038e+07  1.291258e+07       0.532041   276804.609125
# min    3.330011e+06  5.705288e+06       0.160000    96791.900000
# 25%    4.231724e+06  2.564563e+07       0.490000   456712.600000
# 50%    2.954186e+07  3.763837e+07       0.820000   728344.566667
# 75%    3.173940e+07  3.826079e+07       1.360000   794570.666667
# max    3.777824e+07  3.916712e+07       1.880000   866869.700000
#
#        riqueza_per_capita            wti
# count       970500.000000  970500.000000
# mean         15673.632728      82.167917
# std           1265.621530      23.629620
# min          13536.666667      26.210000
# 25%          14768.666667      59.372000
# 50%          15459.333333      93.034286
# 75%          16466.666667      99.600000
# max          18491.000000     113.930000

# %% [markdown]
# ## Análisis descriptivo por columna:

# %% [markdown]
# - Vamos a analizar 100% las siguientes: `sales`,
# `sell_price`,
# `scaled_sell_price`,
# `pi_mean`,
# `poblacion`,
# `Crecimiento_p`,
# `pib_por_estado`,
# `riqueza_per_capita`,
# `wti`.

# %%
pd.options.display.float_format = '{:.4f}'.format

# %% [markdown]
# ### `sales`

# %%
print(sales.sales.describe())
print(f'Median: {sales.sales.median()}')
print(f'Mode: {sales.sales.mode()[0]}') # He puesto el [0] para mostrar solo el valor de la moda porque si no aparece con el indice.  
range_ = max(sales.sales) - min(sales.sales)
print(f"Rango: {range_}")
# Out:
# count   970500.0000
# mean         1.1648
# std          3.7737
# min          0.0000
# 25%          0.0000
# 50%          0.0000
# 75%          1.0000
# max        315.0000
# Name: sales, dtype: float64
# Median: 0.0
# Mode: 0
# Rango: 315

# %% [markdown]
# - Valores nulos:

# %%
print(sales.sales.isnull().sum())
# Out:
# 0

# %% [markdown]
# - Valores unicos:

# %%
print(sales.sales.nunique())
# Out:
# 140

# %% [markdown]
# - Confirmación del tipo de datos de la columna:

# %%
sales.sales.dtype
# Out:
# dtype('int64')

# %% [markdown]
# - Distribución:

# %%
plt.figure(figsize=(6,3))
sns.histplot(sales['sales'], kde=True, bins=50)
plt.title('Distribución de sales')
plt.xlabel('sales')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', linewidth=0.7)
plt.show()

# %% [markdown]
# - Weekly evolution of sales:

# %%
# Asegurar que la columna 'Date' es datetime
sales['date'] = pd.to_datetime(sales['date'])

# Agrupar por mes y calcular el promedio del PIB por mes
sales_semanal = sales.resample('W', on='date')['sales'].mean().reset_index()

plt.figure(figsize=(8, 5))
plt.plot(sales_semanal['date'], sales_semanal['sales'], color='blue', linestyle='-', linewidth=1.5)
plt.title('Weekly evolution of sales')
plt.xlabel('Date')
plt.ylabel('sales weekly average')
plt.grid(True, linestyle='--', linewidth=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Comentarios sobre la columna:

# %% [markdown]
# ### `Sell_price`

# %%
print(sales.sell_price.describe())
print(f'Median: {sales.sell_price.median()}')
print(f'Mode: {sales.sell_price.mode()[0]}') # He puesto el [0] para mostrar solo el valor de la moda porque si no aparece con el indice.  
range_ = max(sales.sell_price) - min(sales.sell_price)
print(f"Rango: {range_}")
# Out:
# count   970500.0000
# mean         4.5330
# std          3.5812
# min          0.0100
# 25%          2.1800
# 50%          3.4800
# 75%          5.9400
# max         44.8400
# Name: sell_price, dtype: float64
# Median: 3.48
# Mode: 2.98
# Rango: 44.830000000000005

# %% [markdown]
# - Valores nulos:

# %%
print(sales.sell_price.isnull().sum())
# Out:
# 0

# %% [markdown]
# - Valores unicos:

# %%
print(sales.sell_price.nunique())
# Out:
# 780

# %% [markdown]
# - Confirmación del tipo de datos de la columna:

# %%
sales.sell_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# - Distribución:

# %%
plt.figure(figsize=(6,3))
sns.histplot(sales['sell_price'], kde=True, bins=50)
plt.title('Distribución de sell_price')
plt.xlabel('sell_price')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', linewidth=0.7)
plt.show()

# %% [markdown]
# - Weekly evolution of sell_price:

# %%
# Asegurar que la columna 'Date' es datetime
sales['date'] = pd.to_datetime(sales['date'])

# Agrupar por mes y calcular el promedio del PIB por mes
sales_semanal = sales.resample('W', on='date')['sell_price'].mean().reset_index()

plt.figure(figsize=(8, 5))
plt.plot(sales_semanal['date'], sales_semanal['sell_price'], color='blue', linestyle='-', linewidth=1.5)
plt.title('Weekly evolution of sell_price')
plt.xlabel('Date')
plt.ylabel('sell_price weekly average')
plt.grid(True, linestyle='--', linewidth=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Comentarios sobre la columna:

# %% [markdown]
# ### `scaled_sell_price`

# %%
print(sales.scaled_sell_price.describe())
print(f'Median: {sales.scaled_sell_price.median()}')
print(f'Mode: {sales.scaled_sell_price.mode()[0]}') # He puesto el [0] para mostrar solo el valor de la moda porque si no aparece con el indice.  
range_ = max(sales.scaled_sell_price) - min(sales.scaled_sell_price)
print(f"Rango: {range_}")
# Out:
# count   970500.0000
# mean         0.0000
# std          1.0000
# min         -1.2630
# 25%         -0.6570
# 50%         -0.2940
# 75%          0.3929
# max         11.2551
# Name: scaled_sell_price, dtype: float64
# Median: -0.2940397736077271
# Mode: -0.4336574333470244
# Rango: 12.518119372225396

# %% [markdown]
# - Valores nulos:

# %%
print(sales.scaled_sell_price.isnull().sum())
# Out:
# 0

# %% [markdown]
# - Valores unicos:

# %%
print(sales.scaled_sell_price.nunique())
# Out:
# 780

# %% [markdown]
# - Confirmación del tipo de datos de la columna:

# %%
sales.scaled_sell_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# - Distribución:

# %%
plt.figure(figsize=(6,3))
sns.histplot(sales['scaled_sell_price'], kde=True, bins=50)
plt.title('Distribución de scaled_sell_price')
plt.xlabel('scaled_sell_price')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', linewidth=0.7)
plt.show()

# %% [markdown]
# - Comentarios sobre la columna:

# %% [markdown]
# ### `pi_mean`

# %%
print(sales.pi_mean.describe())
print(f'Median: {sales.pi_mean.median()}')
print(f'Mode: {sales.pi_mean.mode()[0]}') # He puesto el [0] para mostrar solo el valor de la moda porque si no aparece con el indice.  
range_ = max(sales.pi_mean) - min(sales.pi_mean)
print(f"Rango: {range_}")
# Out:
# count     970500.0000
# mean    18870006.3073
# std     14490382.7949
# min      3330011.1143
# 25%      4231724.2795
# 50%     29541862.1379
# 75%     31739400.8793
# max     37778241.5690
# Name: pi_mean, dtype: float64
# Median: 29541862.13793104
# Mode: 36156027.155172415
# Rango: 34448230.4546798

# %% [markdown]
# - Valores nulos:

# %%
print(sales.pi_mean.isnull().sum())
# Out:
# 0

# %% [markdown]
# - Valores unicos:

# %%
print(sales.pi_mean.nunique())
# Out:
# 18

# %% [markdown]
# - Confirmación del tipo de datos de la columna:

# %%
sales.pi_mean.dtype
# Out:
# dtype('float64')

# %% [markdown]
# - Distribución:

# %%
plt.figure(figsize=(6,3))
sns.histplot(sales['pi_mean'], kde=True, bins=50)
plt.title('Distribución de pi_mean')
plt.xlabel('pi_mean')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', linewidth=0.7)
plt.show()

# %% [markdown]
# - Weekly evolution of pi_mean:

# %%
# Asegurar que la columna 'Date' es datetime
sales['date'] = pd.to_datetime(sales['date'])

# Agrupar por mes y calcular el promedio del PIB por mes
sales_semanal = sales.resample('W', on='date')['pi_mean'].mean().reset_index()

plt.figure(figsize=(8, 5))
plt.plot(sales_semanal['date'], sales_semanal['pi_mean'], color='blue', linestyle='-', linewidth=1.5)
plt.title('Weekly evolution of pi_mean')
plt.xlabel('Date')
plt.ylabel('pi_mean weekly average')
plt.grid(True, linestyle='--', linewidth=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Comentarios sobre la columna:

# %% [markdown]
# ### `poblacion`

# %%
print(sales.poblacion.describe())
print(f'Median: {sales.poblacion.median()}')
print(f'Mode: {sales.poblacion.mode()[0]}') # He puesto el [0] para mostrar solo el valor de la moda porque si no aparece con el indice.  
range_ = max(sales.poblacion) - min(sales.poblacion)
print(f"Rango: {range_}")
# Out:
# count     970500.0000
# mean    27932291.0329
# std     12912580.4933
# min      5705288.0000
# 25%     25645629.0000
# 50%     37638369.0000
# 75%     38260787.0000
# max     39167117.0000
# Name: poblacion, dtype: float64
# Median: 37638369.0
# Mode: 38918045.0
# Rango: 33461829.0

# %% [markdown]
# - Valores nulos:

# %%
print(sales.poblacion.isnull().sum())
# Out:
# 0

# %% [markdown]
# - Valores unicos:

# %%
print(sales.poblacion.nunique())
# Out:
# 18

# %% [markdown]
# - Confirmación del tipo de datos de la columna:

# %%
sales.poblacion.dtype
# Out:
# dtype('float64')

# %% [markdown]
# - Distribución:

# %%
plt.figure(figsize=(6,3))
sns.histplot(sales['poblacion'], kde=True, bins=50)
plt.title('Distribución de poblacion')
plt.xlabel('poblacion')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', linewidth=0.7)
plt.show()

# %% [markdown]
# - Comentarios sobre la columna:

# %% [markdown]
# ### `Crecimiento_p`

# %%
print(sales.Crecimiento_p.describe())
print(f'Median: {sales.Crecimiento_p.median()}')
print(f'Mode: {sales.Crecimiento_p.mode()[0]}') # He puesto el [0] para mostrar solo el valor de la moda porque si no aparece con el indice.  
range_ = max(sales.Crecimiento_p) - min(sales.Crecimiento_p)
print(f"Rango: {range_}")
# Out:
# count   970500.0000
# mean         0.8953
# std          0.5320
# min          0.1600
# 25%          0.4900
# 50%          0.8200
# 75%          1.3600
# max          1.8800
# Name: Crecimiento_p, dtype: float64
# Median: 0.82
# Mode: 0.82
# Rango: 1.72

# %% [markdown]
# - Valores nulos:

# %%
print(sales.Crecimiento_p.isnull().sum())
# Out:
# 0

# %% [markdown]
# - Valores unicos:

# %%
print(sales.Crecimiento_p.nunique())
# Out:
# 16

# %% [markdown]
# - Confirmación del tipo de datos de la columna:

# %%
sales.Crecimiento_p.dtype
# Out:
# dtype('float64')

# %% [markdown]
# - Distribución:

# %%
plt.figure(figsize=(6,3))
sns.histplot(sales['Crecimiento_p'], kde=True, bins=50)
plt.title('Distribución de Crecimiento_p')
plt.xlabel('Crecimiento_p')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', linewidth=0.7)
plt.show()

# %% [markdown]
# - Comentarios sobre la columna:

# %% [markdown]
# ### `pib_por_estado`

# %%
print(sales.pib_por_estado.describe())
print(f'Median: {sales.pib_por_estado.median()}')
print(f'Mode: {sales.pib_por_estado.mode()[0]}') # He puesto el [0] para mostrar solo el valor de la moda porque si no aparece con el indice.  
range_ = max(sales.pib_por_estado) - min(sales.pib_por_estado)
print(f"Rango: {range_}")
# Out:
# count   970500.0000
# mean    560693.4258
# std     276804.6091
# min      96791.9000
# 25%     456712.6000
# 50%     728344.5667
# 75%     794570.6667
# max     866869.7000
# Name: pib_por_estado, dtype: float64
# Median: 728344.5666666668
# Mode: 729999.7666666666
# Rango: 770077.8

# %% [markdown]
# - Valores nulos:

# %%
print(sales.pib_por_estado.isnull().sum())
# Out:
# 0

# %% [markdown]
# - Valores unicos:

# %%
print(sales.pib_por_estado.nunique())
# Out:
# 66

# %% [markdown]
# - Confirmación del tipo de datos de la columna:

# %%
sales.pib_por_estado.dtype
# Out:
# dtype('float64')

# %% [markdown]
# - Distribución:

# %%
plt.figure(figsize=(6,3))
sns.histplot(sales['pib_por_estado'], kde=True, bins=50)
plt.title('Distribución de pib_por_estado')
plt.xlabel('pib_por_estado')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', linewidth=0.7)
plt.show()

# %% [markdown]
# - Weekly evolution of rpc

# %%
# Asegurar que la columna 'Date' es datetime
sales['date'] = pd.to_datetime(sales['date'])

# Agrupar por mes y calcular el promedio del PIB por mes
sales_semanal = sales.resample('W', on='date')['pib_por_estado'].mean().reset_index()

plt.figure(figsize=(8, 5))
plt.plot(sales_semanal['date'], sales_semanal['pib_por_estado'], color='blue', linestyle='-', linewidth=1.5)
plt.title('Weekly evolution of pib_por_estado')
plt.xlabel('date')
plt.ylabel('pib_por_estado weekly average')
plt.grid(True, linestyle='--', linewidth=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Comentarios sobre la columna:

# %% [markdown]
# ### `wti`

# %%
print(sales.wti.describe())
print(f'Median: {sales.wti.median()}')
print(f'Mode: {sales.wti.mode()[0]}') # He puesto el [0] para mostrar solo el valor de la moda porque si no aparece con el indice.  
range_ = max(sales.wti) - min(sales.wti)
print(f"Rango: {range_}")
# Out:
# count   970500.0000
# mean        82.1679
# std         23.6296
# min         26.2100
# 25%         59.3720
# 50%         93.0343
# 75%         99.6000
# max        113.9300
# Name: wti, dtype: float64
# Median: 93.03428571428572
# Mode: 31.77578947368421
# Rango: 87.72

# %% [markdown]
# - Valores nulos:

# %%
print(sales.wti.isnull().sum())
# Out:
# 0

# %% [markdown]
# - Valores unicos:

# %%
print(sales.wti.nunique())
# Out:
# 1235

# %% [markdown]
# - Confirmación del tipo de datos de la columna:

# %%
sales.wti.dtype
# Out:
# dtype('float64')

# %% [markdown]
# - Distribución:

# %%
plt.figure(figsize=(6,3))
sns.histplot(sales['wti'], kde=True, bins=50)
plt.title('Distribución de wti')
plt.xlabel('wti')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', linewidth=0.7)
plt.show()

# %% [markdown]
# - Daily evolution of wti

# %%
sales['date'] = pd.to_datetime(sales['date'])  # Asegurate de que sales['Date'] sea tipo datetime

plt.figure(figsize=(8, 5))
plt.plot(sales['date'], sales['wti'], color='blue', linestyle='-', marker='', linewidth=1)
plt.title('Daily evolution of wti')
plt.xlabel('Fecha')
plt.ylabel('wti')
plt.grid(True, linestyle='--', linewidth=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Comentarios sobre la columna:

# %% [markdown]
# ### `riqueza_per_capita`

# %%
print(sales.riqueza_per_capita.describe())
print(f'Median: {sales.riqueza_per_capita.median()}')
print(f'Mode: {sales.riqueza_per_capita.mode()[0]}') # He puesto el [0] para mostrar solo el valor de la moda porque si no aparece con el indice.  
range_ = max(sales.riqueza_per_capita) - min(sales.riqueza_per_capita)
print(f"Rango: {range_}")
# Out:
# count   970500.0000
# mean     15673.6327
# std       1265.6215
# min      13536.6667
# 25%      14768.6667
# 50%      15459.3333
# 75%      16466.6667
# max      18491.0000
# Name: riqueza_per_capita, dtype: float64
# Median: 15459.333333333334
# Mode: 15256.0
# Rango: 4954.333333333334

# %% [markdown]
# - Valores nulos:

# %%
print(sales.riqueza_per_capita.isnull().sum())
# Out:
# 0

# %% [markdown]
# - Valores unicos:

# %%
print(sales.riqueza_per_capita.nunique())
# Out:
# 66

# %% [markdown]
# - Confirmación del tipo de datos de la columna:

# %%
sales.riqueza_per_capita.dtype
# Out:
# dtype('float64')

# %% [markdown]
# - Distribución:

# %%
plt.figure(figsize=(6,3))
sns.histplot(sales['riqueza_per_capita'], kde=True, bins=50)
plt.title('Distribución de riqueza_per_capita')
plt.xlabel('riqueza_per_capita')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', linewidth=0.7)
plt.show()

# %% [markdown]
# - Comentarios sobre la columna:
